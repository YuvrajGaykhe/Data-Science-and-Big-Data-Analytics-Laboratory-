# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, metrics
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/Datasets/boston.csv")
df
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       18.7  394.63   2.94  33.4
# 3       18.7  396.90   5.33  36.2
# 4       15.2  395.60  12.43  22.9
# ..       ...     ...    ...   ...
# 328     19.2  395.77  15.10  17.5
# 329     21.0  391.99   9.67  22.4
# 330     21.0  396.90   9.08  20.6
# 331     21.0  396.90   5.64  23.9
# 332     21.0  396.90   7.88  11.9
#
# [333 rows x 15 columns]

# %%
X = df.drop(['medv', 'ID'], axis=1)
y = df['medv']

# %%
X_train, X_test,\
y_train, y_test = train_test_split(X, y,
test_size=0.4,
random_state=1)

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Coefficients: ', reg.coef_)
print('Variance score: {}'.format(reg.score(X_test, y_test)))
# Out:
# Coefficients:  [-1.02694324e-01  4.87411335e-02 -3.13287671e-03  2.42524902e+00
#  -1.52231205e+01  2.71831970e+00  5.66012777e-03 -1.96760560e+00
#   4.15398829e-01 -1.62896339e-02 -1.07538701e+00  1.15997474e-02
#  -7.10235724e-01]
# Variance score: 0.6830979145895071

# %%
plt.figure(figsize=(10, 7))
plt.scatter(y_test, reg.predict(X_test), alpha=0.7)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs. Predicted Home Prices")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.grid(True)
plt.show()
